# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D
from keras.layers.core import Dense, Flatten
from keras.optimizers import RMSprop

from snake_game import snake_game
from agent import Agent

print(tf.__version__)
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0713 23:25:47.702877 4571391424 deprecation.py:323] From /usr/local/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2.0.0-beta1

# %%
def main():
    game_width = 12
    game_height = 9
    nb_frames = 4
    actions = ((-1, 0), (1, 0), (0, -1), (0, 1), (0, 0))

    # Recipe of deep reinforcement learning model
    model = Sequential()
    model.add(Convolution2D(
        16,
        # nb_row=3,
        # nb_col=3,
        (3,3),
        activation='relu',
        input_shape=(nb_frames, game_height, game_width),
        data_format='channels_first')) # This is important 
    # model.add(Convolution2D(32, nb_row=3, nb_col=3, activation='relu'))
    model.add(Convolution2D(32, (3,3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(len(actions)))
    model.compile(RMSprop(), 'MSE')

    agent = Agent(
        model, nb_frames, snake_game, actions, size=(game_width, game_height))
    agent.train(nb_epochs=10000, batch_size=64, gamma=0.8, save_model=True)
    agent.play(nb_rounds=10)


if __name__ == '__main__':
    main()
# Out:
# Epoch    100/10000, loss: 0.098871, epsilon: 0.982 [104s]
# Epoch    200/10000, loss: 0.038580, epsilon: 0.964 [118s]
# Epoch    300/10000, loss: 0.041867, epsilon: 0.946 [128s]
# Epoch    400/10000, loss: 0.043047, epsilon: 0.928 [110s]
# Epoch    500/10000, loss: 0.060559, epsilon: 0.910 [116s]
# Epoch    600/10000, loss: 0.030203, epsilon: 0.892 [122s]
# Epoch    700/10000, loss: 0.060985, epsilon: 0.874 [147s]
# Epoch    800/10000, loss: 0.043664, epsilon: 0.856 [120s]
# Epoch    900/10000, loss: 0.126807, epsilon: 0.838 [123s]
# Epoch   1000/10000, loss: 0.049354, epsilon: 0.820 [104s]
# Epoch   1100/10000, loss: 0.085582, epsilon: 0.802 [127s]
# Epoch   1200/10000, loss: 0.034865, epsilon: 0.784 [126s]
# Epoch   1300/10000, loss: 0.025825, epsilon: 0.766 [129s]
# Epoch   1400/10000, loss: 0.041526, epsilon: 0.748 [121s]
# Epoch   1500/10000, loss: 0.225407, epsilon: 0.730 [130s]
# Epoch   1600/10000, loss: 0.143838, epsilon: 0.712 [146s]
# Epoch   1700/10000, loss: 0.205234, epsilon: 0.694 [138s]
# Epoch   1800/10000, loss: 0.075224, epsilon: 0.676 [144s]
# Epoch   1900/10000, loss: 0.036057, epsilon: 0.658 [149s]
# Epoch   2000/10000, loss: 0.095336, epsilon: 0.640 [131s]
# Epoch   2100/10000, loss: 0.051160, epsilon: 0.622 [171s]
# Epoch   2200/10000, loss: 0.057558, epsilon: 0.604 [169s]
# Epoch   2300/10000, loss: 0.087729, epsilon: 0.586 [172s]
# Epoch   6500/10000, loss: 3.835765, epsilon: 0.100 [430s]
# Epoch   6600/10000, loss: 2.701455, epsilon: 0.100 [397s]
# Epoch   6700/10000, loss: 3.479994, epsilon: 0.100 [455s]
# Epoch   6800/10000, loss: 0.510058, epsilon: 0.100 [469s]
# Epoch   6900/10000, loss: 0.353847, epsilon: 0.100 [533s]
# Epoch   7000/10000, loss: 2.960203, epsilon: 0.100 [459s]
# Epoch   7100/10000, loss: 2.620473, epsilon: 0.100 [444s]
# Epoch   7200/10000, loss: 2.722195, epsilon: 0.100 [480s]
# Epoch   7300/10000, loss: 5.253680, epsilon: 0.100 [491s]
# Epoch   7400/10000, loss: 4.847129, epsilon: 0.100 [448s]
# Epoch   7500/10000, loss: 1.075608, epsilon: 0.100 [410s]
# Epoch   7600/10000, loss: 2.386881, epsilon: 0.100 [428s]
# Epoch   7700/10000, loss: 1.443394, epsilon: 0.100 [486s]
# Epoch   7800/10000, loss: 0.979934, epsilon: 0.100 [455s]
# Epoch   7900/10000, loss: 1.607288, epsilon: 0.100 [449s]
# Epoch   8000/10000, loss: 2.825952, epsilon: 0.100 [407s]
# Epoch   8100/10000, loss: 3.995003, epsilon: 0.100 [469s]
# Epoch   8200/10000, loss: 4.742276, epsilon: 0.100 [466s]
# Epoch   8300/10000, loss: 3.814763, epsilon: 0.100 [457s]
# Epoch   8400/10000, loss: 0.412458, epsilon: 0.100 [441s]
# Epoch   8500/10000, loss: 1.549935, epsilon: 0.100 [489s]
# Epoch   8600/10000, loss: 0.363543, epsilon: 0.100 [402s]
# Epoch   8700/10000, loss: 3.816029, epsilon: 0.100 [494s]
# Epoch   8800/10000, loss: 0.693817, epsilon: 0.100 [484s]
# Epoch   8900/10000, loss: 4.875269, epsilon: 0.100 [438s]
# Epoch   9000/10000, loss: 3.669516, epsilon: 0.100 [476s]
# Epoch   9100/10000, loss: 5.522984, epsilon: 0.100 [452s]
# Epoch   9200/10000, loss: 1.451567, epsilon: 0.100 [563s]
# Epoch   9300/10000, loss: 2.490958, epsilon: 0.100 [540s]
# Epoch   9400/10000, loss: 2.428622, epsilon: 0.100 [503s]
# Epoch   9500/10000, loss: 3.960717, epsilon: 0.100 [464s]
# Epoch   9600/10000, loss: 0.532885, epsilon: 0.100 [464s]
# Epoch   9700/10000, loss: 2.569717, epsilon: 0.100 [469s]
# Epoch   9800/10000, loss: 3.309762, epsilon: 0.100 [453s]
# Epoch   9900/10000, loss: 1.337570, epsilon: 0.100 [462s]
# Epoch  10000/10000, loss: 3.306901, epsilon: 0.100 [499s]
# Saved   18 frames for game   1
# Saved   87 frames for game   2
# Saved   84 frames for game   3
# Saved    8 frames for game   4
# Saved   29 frames for game   5
# Saved   78 frames for game   6
# Saved   44 frames for game   7
# Saved   63 frames for game   8
# Saved   38 frames for game   9
# Saved   45 frames for game  10

# %% [markdown]
# ### Proceeding
# I modify the code in `snake_game.py` and `agent.py` so it can be compile in __python 3.7__ and __tensorflow 2.0.0__
